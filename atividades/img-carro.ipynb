# %% [markdown]
# ### Imports

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Image instance

# %%
img = cv2.imread('carro.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img.shape
# Out:
# (655, 984, 3)

# %% [markdown]
# ### Image plot

# %%
plt.imshow(img)
plt.show()
