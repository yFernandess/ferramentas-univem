# %% [markdown]
# ## Importação de bibliotecas

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregamento da imagem

# %%
img = cv2.imread("ferramentas-produtivas.JPG")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img.shape

plt.imshow(img)
plt.show()
